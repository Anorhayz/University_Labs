# %%
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt

image = Image.open("grey_swim.jpg") #sw.jpg
pix = image.load()

# %%
row = image.size[0]
col = image.size[1]
gamma = 0.75
for x in range(1 , row):
    for y in range(1, col):
        value = pow(image.getpixel((x,y))[0]/255,(1/gamma))*255
        if value >= 255 :
            value = 255
        result_img.putpixel((x,y), int(value))
result_img.save("gamma_corection.png")

# %%
plt.figure(figsize=(15,10))
y = image.histogram()
y = y[0:256]
x = np.arange(len(y))
plt.subplot(221)
plt.title("image histogram")
plt.bar(x, y)
# Out:
# <BarContainer object of 256 artists>

# %%
plt.figure(figsize=(15,10))
plt.subplot(222)
y = result_img.histogram()
x = np.arange(len(y))
plt.title("gamma corection histogram")
plt.bar(x, y)
# Out:
# <BarContainer object of 256 artists>
